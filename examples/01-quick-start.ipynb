# %% [markdown]
# # Loclean Quick Start
#
# This notebook demonstrates the core features of Loclean:
# - Structured extraction with Pydantic
# - Data cleaning with DataFrames
# - Privacy scrubbing
# - Working with different backends (Pandas/Polars)
#
# > **📚 Full Documentation:** [https://nxank4.github.io/loclean](https://nxank4.github.io/loclean)

# %%
import loclean
import polars as pl
import pandas as pd

# %% [markdown]
# ## 1. Structured Extraction with Pydantic
#
# Extract structured data from unstructured text with guaranteed schema compliance:

# %%
from pydantic import BaseModel

class Product(BaseModel):
    name: str
    price: int
    color: str

# Extract from text
item = loclean.extract("Selling red t-shirt for 50k", schema=Product)
print(f"Name: {item.name}")
print(f"Price: {item.price}")
print(f"Color: {item.color}")
# Out:
# 2026-01-11 18:53:05,704 - loclean.inference.local.llama_cpp - INFO - Using adapter: Phi3Adapter for model: phi-3-mini
# 2026-01-11 18:53:05,705 - loclean.inference.local.downloader - INFO - Model found at /home/nxank4/.cache/loclean/Phi-3-mini-4k-instruct-q4.gguf
# 2026-01-11 18:53:05,706 - loclean.inference.local.llama_cpp - INFO - Loading model from /home/nxank4/.cache/loclean/Phi-3-mini-4k-instruct-q4.gguf...
# 2026-01-11 18:53:10,806 - loclean.inference.local.llama_cpp - INFO - LlamaCppEngine initialized successfully with model: phi-3-mini
# Extraction attempt 1 failed: the JSON object must be str, bytes or bytearray, not dict
# Extraction attempt 2 failed: the JSON object must be str, bytes or bytearray, not dict
# Extraction attempt 3 failed: the JSON object must be str, bytes or bytearray, not dict
# Max retries (3) exceeded for text: 'Selling red t-shirt for 50k...'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       6     color: str
#       8 # Extract from text
# ----> 9 item = loclean.extract("Selling red t-shirt for 50k", schema=Product)
#      10 print(f"Name: {item.name}")
#      11 print(f"Price: {item.price}")
#
# File ~/GitHub/loclean/src/loclean/__init__.py:330, in extract(input_data, schema, instruction, target_col, output_type, max_retries, model_name, cache_dir, n_ctx, n_gpu_layers, **engine_kwargs)
#     325 if isinstance(input_data, str):
#     326     # String extraction
#     327     extractor = Extractor(
#     328         inference_engine=inference_engine, cache=cache, max_retries=max_retries
#     329     )
# --> 330     return extractor.extract(input_data, schema, instruction)
#     331 else:
#     332     # DataFrame extraction
#     333     if target_col is None:
#
# File ~/GitHub/loclean/src/loclean/extraction/extractor.py:101, in Extractor.extract(self, text, schema, instruction)
#      96 result = self._extract_with_retry(
#      97     text, schema, final_instruction, retry_count=0
#      98 )
#     100 if result is None:
# --> 101     raise ValidationError(
#     102         f"Failed to extract valid {schema.__name__} from text "
#     103         f"after {self.max_retries} retries"
#     104     )
#     106 # Cache result
#     107 if self.cache:
#
# TypeError: ValidationError.__new__() missing 1 required positional argument: 'line_errors'

# %% [markdown]
# ## 2. Working with Tabular Data (Polars)
#
# Process entire DataFrames with automatic batch processing:

# %%
# Create DataFrame with messy data
df = pl.DataFrame({
    "weight": ["5kg", "3.5 kg", "5000g", "2.2kg"]
})

print("Input Data:")
print(df)

# Clean the entire column
result = loclean.clean(
    df,
    target_col="weight",
    instruction="Convert all weights to kg"
)

# View results
print("\nCleaned Results:")
print(result.select(["weight", "clean_value", "clean_unit"]))

# %% [markdown]
# ## 3. Working with Pandas
#
# Loclean works seamlessly with Pandas:

# %%
# Create Pandas DataFrame
df_pandas = pd.DataFrame({
    "description": ["Selling red t-shirt for 50k"]
})

# Extract structured data
result = loclean.extract(df_pandas, schema=Product, target_col="description")
print(f"Result type: {type(result)}")
print(result)

# %% [markdown]
# ## 4. Privacy Scrubbing
#
# Scrub sensitive PII data locally:

# %%
# Text with PII
text = "Contact John Doe at john@example.com or 555-1234"

# Scrub PII (default: mask mode)
cleaned = loclean.scrub(text, mode="mask")
print(f"Original: {text}")
print(f"Cleaned:  {cleaned}")

# %% [markdown]
# ## 5. Extraction with DataFrames (Polars)
#
# Extract structured data from DataFrame columns:

# %%
df = pl.DataFrame({
    "description": [
        "Selling red t-shirt for 50k",
        "Blue jeans available for 30k"
    ]
})

result = loclean.extract(df, schema=Product, target_col="description")

# Query extracted data using Polars Struct
filtered = result.filter(
    pl.col("description_extracted").struct.field("price") > 40000
)
print("Products with price > 40k:")
print(filtered)

# %% [markdown]
# ## Next Steps
#
# - **Data Cleaning:** See [02-data-cleaning.ipynb](./02-data-cleaning.ipynb) for detailed cleaning examples
# - **Privacy Scrubbing:** See [03-privacy-scrubbing.ipynb](./03-privacy-scrubbing.ipynb) for PII removal
# - **Structured Extraction:** See [04-structured-extraction.ipynb](./04-structured-extraction.ipynb) for complex schemas
# - **Full Documentation:** [https://nxank4.github.io/loclean](https://nxank4.github.io/loclean)
